# %%
### Loading required modules

import numpy as np
import tensorflow as tf
import os,sys
import datetime
import pickle
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Activation, Dense
from tensorflow.keras.layers import Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
import cv2
from matplotlib import pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

tf.config.list_physical_devices('GPU')

path="/home/ubuntu/pediatric_dental_age_prediction/raw/"

print("Loaded all modules")
# Out:
# 2023-11-12 23:18:34.087131: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-12 23:18:35.502495: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loaded all modules
# 2023-11-12 23:18:39.006810: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-12 23:18:39.054126: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-12 23:18:39.056229: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
### Prep for training data (14.8 GB RAM used for 2165 images)

X_train_li = [] ### arrays of augmented images
Y_train_li = [] ### ages of corresponding images
subj_train_li = []
fn_train_li = []

trainAgeDic={}
with open(path+"train_age.txt") as ageFile:
    for line in ageFile.readlines():
        subj, corrAgeStr = line.rstrip().split("\t")
        trainAgeDic[subj] = float(corrAgeStr)

for imgFn in os.listdir(path+"train_aug"):
    cvImgNorm = cv2.imread(path+"train_aug/"+imgFn)/255
    subj = "_".join(imgFn.split("_")[:2])
    cvImgAge = trainAgeDic[subj]

    X_train_li.append(cvImgNorm)
    Y_train_li.append(cvImgAge)
    subj_train_li.append(subj)
    fn_train_li.append(imgFn)

X_train = np.array(X_train_li)
Y_train = np.array(Y_train_li)
print("Prep for train set done")
# Out:
# Prep for train set done

# %%
### Prep for testing data (2.0 GB RAM used for 329 images)

X_test_li = [] ### arrays of augmented images
Y_test_li = [] ### ages of corresponding images
subj_test_li = []
fn_test_li = []

testAgeDic={}
with open(path+"test_age.txt") as ageFile:
    for line in ageFile.readlines():
        subj, corrAgeStr = line.rstrip().split("\t")
        testAgeDic[subj] = float(corrAgeStr)

for imgFn in os.listdir(path+"test_aug"):
    cvImgNorm = cv2.imread(path+"test_aug/"+imgFn)/255
    subj = "_".join(imgFn.split("_")[:2])
    cvImgAge = testAgeDic[subj]

    X_test_li.append(cvImgNorm)
    Y_test_li.append(cvImgAge)
    subj_test_li.append(subj)
    fn_test_li.append(imgFn)

X_test = np.array(X_test_li)
Y_test = np.array(Y_test_li)
print("Prep for test set done")
# Out:
# Prep for test set done

# %%
### Defining CNN+FCL regression model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Activation, Dense
from tensorflow.keras.layers import Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD

def createCNN(inputShape,
              cnnFilterNumbersGiven,
              fclFilterNumbersGiven,
              cnnDropoutRateGiven,
              fclDropoutRateGiven,
              cnnBatchNormBoolGiven,
              fclBatchNormBoolGiven,
              cnnActivationFunctionGiven,
              fclActivationFunctionGiven):
    chanDim = -1

    #### CNN layer

    model = Sequential()
    
    for (i,f) in enumerate(cnnFilterNumbersGiven):
        # CONV => RELU => BN => POOL => DropOut
        if i == 0:
            model.add(Conv2D(f, (3, 3), padding="same",
                   activation=cnnActivationFunctionGiven,
                            input_shape = inputShape))
        else:
            model.add(Conv2D(f, (3, 3), padding="same",
                   activation=cnnActivationFunctionGiven))
        if cnnBatchNormBoolGiven:
            model.add(BatchNormalization(axis=chanDim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        if cnnDropoutRateGiven!=0:
            model.add(Dropout(cnnDropoutRateGiven))
    
    model.add(Flatten())

    #### FC Layer
    for f in fclFilterNumbersGiven:
        model.add(Dense(f, activation=fclActivationFunctionGiven))
        if fclBatchNormBoolGiven:
            model.add(BatchNormalization(axis=chanDim))
        if fclDropoutRateGiven != 0:
            model.add(Dropout(fclDropoutRateGiven))
    
    model.add(Dense(1, activation = "linear"))

    print("CNN+FCL model built with tensorflow.keras")
    
    return(model)

# %%
### Defining CNN+FCL models with parameters

## Model part
cnnFilterNumbers = [4, 8, 16, 32, 64]
cnnDropoutRate = 0.25
cnnBatchNormBool = True
cnnActivationFunction = "relu"

fclFilterNumbers = [16]
fclDropoutRate = 0.5
fclBatchNormBool = True 
fclActivationFunction = "relu"


## Learning part

lossFunction = "mean_squared_error"

learningRate = 1e-3
epochSize = 200
batchSize = 8

optimizer = "Adam"

def optimizer_select(optimizer, learningRate
              ):
    
    if optimizer == "Adam":
        opt = Adam(learning_rate=learningRate)
    elif optimizer == "RMSprop":
        opt = RMSprop(learning_rate=learningRate)
    elif optimizer == "SGD":
        opt = SGD(learning_rate=learningRate)
    
    return(opt)


model = createCNN(inputShape = X_train.shape[1:],
                  cnnFilterNumbersGiven = cnnFilterNumbers,
                  fclFilterNumbersGiven = fclFilterNumbers,
                  cnnDropoutRateGiven = cnnDropoutRate,
                  fclDropoutRateGiven = fclDropoutRate,
                  cnnBatchNormBoolGiven = cnnBatchNormBool,
                  fclBatchNormBoolGiven = fclBatchNormBool,
                  cnnActivationFunctionGiven = cnnActivationFunction,
                  fclActivationFunctionGiven = fclActivationFunction)

model.compile(loss=lossFunction, optimizer = optimizer_select(optimizer, learningRate))
# Out:
# 2023-11-12 23:19:20.330458: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-12 23:19:20.332672: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-12 23:19:20.334551: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-12 23:19:20.849824: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-12 23:19:20.850834: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-12 23:19:20.851599: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-12 23:19:20.852324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20591 MB memory:  -> device: 0, name: NVIDIA A10G, pci bus id: 0000:00:1e.0, compute capability: 8.6
# CNN+FCL model built with tensorflow.keras

# %%
### Training the model

print("Training the model...")

modelHistory = model.fit(x=X_train, y=Y_train,
                    validation_data = (X_test, Y_test),
    epochs=epochSize, batch_size=batchSize, verbose = 1)
# Out:
# Training the model...
# 2023-11-12 23:19:27.366895: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3400531968 exceeds 10% of free system memory.
# 2023-11-12 23:19:29.096249: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3400531968 exceeds 10% of free system memory.
# Epoch 1/200
# 2023-11-12 23:19:31.573288: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-12 23:19:33.037518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8903
# 2023-11-12 23:19:33.789574: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-12 23:19:33.815890: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8c8cafda50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-12 23:19:33.815915: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A10G, Compute Capability 8.6
# 2023-11-12 23:19:33.896388: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-12 23:19:34.189238: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 271/271 [==============================] - 11s 15ms/step - loss: 47.6175 - val_loss: 64.0769
# Epoch 2/200
# 271/271 [==============================] - 3s 11ms/step - loss: 18.5961 - val_loss: 1236.4026
# Epoch 3/200
# 271/271 [==============================] - 3s 11ms/step - loss: 7.2921 - val_loss: 86653.6562
# Epoch 4/200
# 271/271 [==============================] - 3s 11ms/step - loss: 6.6315 - val_loss: 2163.9858
# Epoch 5/200
# 271/271 [==============================] - 3s 11ms/step - loss: 6.8765 - val_loss: 7047.6738
# Epoch 6/200
# 271/271 [==============================] - 3s 11ms/step - loss: 5.9951 - val_loss: 9177.5215
# Epoch 7/200
# 271/271 [==============================] - 3s 11ms/step - loss: 5.2949 - val_loss: 4218.4683
# Epoch 8/200
# 271/271 [==============================] - 3s 11ms/step - loss: 5.1297 - val_loss: 15055.0166
# Epoch 9/200
# 271/271 [==============================] - 3s 11ms/step - loss: 4.6959 - val_loss: 11050.1523
# Epoch 10/200
# 271/271 [==============================] - 3s 11ms/step - loss: 4.6536 - val_loss: 641.7096
# Epoch 11/200
# 271/271 [==============================] - 3s 11ms/step - loss: 5.0384 - val_loss: 832.9016
# Epoch 12/200
# 271/271 [==============================] - 3s 11ms/step - loss: 4.3846 - val_loss: 8.5317
# Epoch 13/200
# 271/271 [==============================] - 3s 11ms/step - loss: 4.3535 - val_loss: 500.3282
# Epoch 14/200
# 271/271 [==============================] - 3s 11ms/step - loss: 4.2839 - val_loss: 194.5354
# Epoch 15/200
# 271/271 [==============================] - 3s 11ms/step - loss: 4.2301 - val_loss: 10.1283
# Epoch 16/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.9908 - val_loss: 14.4645
# Epoch 17/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.7902 - val_loss: 9.9460
# Epoch 18/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.7543 - val_loss: 5.4743
# Epoch 19/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.6621 - val_loss: 3.8945
# Epoch 20/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.4359 - val_loss: 4.7566
# Epoch 21/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.5729 - val_loss: 15.7189
# Epoch 22/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.4585 - val_loss: 3.1019
# Epoch 23/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.5148 - val_loss: 184.9475
# Epoch 24/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.8961 - val_loss: 22606.9453
# Epoch 25/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.4258 - val_loss: 2091.0493
# Epoch 26/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.0487 - val_loss: 15397.7324
# Epoch 27/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.1554 - val_loss: 7970.0151
# Epoch 28/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.8862 - val_loss: 2604.5171
# Epoch 29/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.8685 - val_loss: 3115.1941
# Epoch 30/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.8670 - val_loss: 26921.6895
# Epoch 31/200
# 271/271 [==============================] - 3s 11ms/step - loss: 4.6382 - val_loss: 2.7589
# Epoch 32/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.8908 - val_loss: 4.4145
# Epoch 33/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.2711 - val_loss: 52.1976
# Epoch 34/200
# 271/271 [==============================] - 3s 11ms/step - loss: 3.1811 - val_loss: 16.4375
# Epoch 35/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.8591 - val_loss: 12.6073
# Epoch 36/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.7207 - val_loss: 3.3954
# Epoch 37/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.7365 - val_loss: 13.7707
# Epoch 38/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.7515 - val_loss: 3.2551
# Epoch 39/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.6188 - val_loss: 5.5910
# Epoch 40/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.4747 - val_loss: 3.5949
# Epoch 41/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.4316 - val_loss: 3.0878
# Epoch 42/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.2426 - val_loss: 3.3958
# Epoch 43/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.1776 - val_loss: 3.3546
# Epoch 44/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.0464 - val_loss: 3.1773
# Epoch 45/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.1456 - val_loss: 1.9488
# Epoch 46/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.3273 - val_loss: 3.6091
# Epoch 47/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.1359 - val_loss: 3.3018
# Epoch 48/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.0575 - val_loss: 3.2574
# Epoch 49/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.0630 - val_loss: 2.1066
# Epoch 50/200
# 271/271 [==============================] - 3s 11ms/step - loss: 2.0247 - val_loss: 6.4049
# Epoch 51/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.8333 - val_loss: 1.3601
# Epoch 52/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.8569 - val_loss: 1.4814
# Epoch 53/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.8670 - val_loss: 1.8477
# Epoch 54/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.8239 - val_loss: 2.1286
# Epoch 55/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.6172 - val_loss: 1.8551
# Epoch 56/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.6394 - val_loss: 1.6923
# Epoch 57/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.6386 - val_loss: 2.3135
# Epoch 58/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.6818 - val_loss: 1.5435
# Epoch 59/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.6103 - val_loss: 1.3586
# Epoch 60/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.6263 - val_loss: 1.6754
# Epoch 61/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.5518 - val_loss: 1.9667
# Epoch 62/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.5627 - val_loss: 2.0113
# Epoch 63/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.5960 - val_loss: 1.3467
# Epoch 64/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.4497 - val_loss: 2.4219
# Epoch 65/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.4979 - val_loss: 1.2896
# Epoch 66/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.4125 - val_loss: 1.6575
# Epoch 67/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.3296 - val_loss: 1.7173
# Epoch 68/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.3255 - val_loss: 1.8232
# Epoch 69/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.5453 - val_loss: 1.4694
# Epoch 70/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.4289 - val_loss: 1.3304
# Epoch 71/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.3531 - val_loss: 1.5463
# Epoch 72/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.3869 - val_loss: 1.4627
# Epoch 73/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.3498 - val_loss: 1.4928
# Epoch 74/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.2911 - val_loss: 1.3388
# Epoch 75/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.3088 - val_loss: 1.3807
# Epoch 76/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.1444 - val_loss: 1.2759
# Epoch 77/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.2817 - val_loss: 1.4525
# Epoch 78/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.2475 - val_loss: 1.8597
# Epoch 79/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.2006 - val_loss: 1.5600
# Epoch 80/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.2048 - val_loss: 1.7083
# Epoch 81/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.1772 - val_loss: 1.6130
# Epoch 82/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.2330 - val_loss: 1.7421
# Epoch 83/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.2248 - val_loss: 1.5753
# Epoch 84/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.1999 - val_loss: 2.3640
# Epoch 85/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0988 - val_loss: 1.1129
# Epoch 86/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.1391 - val_loss: 1.2395
# Epoch 87/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.1237 - val_loss: 1.2561
# Epoch 88/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.1201 - val_loss: 1.4484
# Epoch 89/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0609 - val_loss: 1.4176
# Epoch 90/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0086 - val_loss: 1.3624
# Epoch 91/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0637 - val_loss: 2.5472
# Epoch 92/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0913 - val_loss: 1.6430
# Epoch 93/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0651 - val_loss: 1.5493
# Epoch 94/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9432 - val_loss: 1.0517
# Epoch 95/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0024 - val_loss: 1.7017
# Epoch 96/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.1519 - val_loss: 1.1934
# Epoch 97/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0957 - val_loss: 1.2120
# Epoch 98/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0423 - val_loss: 1.3574
# Epoch 99/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0592 - val_loss: 1.5363
# Epoch 100/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.1048 - val_loss: 1.4839
# Epoch 101/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0214 - val_loss: 1.1893
# Epoch 102/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.1758 - val_loss: 1.1739
# Epoch 103/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9944 - val_loss: 1.3440
# Epoch 104/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9926 - val_loss: 2.3333
# Epoch 105/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0453 - val_loss: 1.2507
# Epoch 106/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0001 - val_loss: 1.2988
# Epoch 107/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0584 - val_loss: 1.4511
# Epoch 108/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0568 - val_loss: 1.1419
# Epoch 109/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9702 - val_loss: 1.4581
# Epoch 110/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9652 - val_loss: 1.1405
# Epoch 111/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9915 - val_loss: 1.1453
# Epoch 112/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0202 - val_loss: 1.2685
# Epoch 113/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0111 - val_loss: 1.3581
# Epoch 114/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0577 - val_loss: 1.4357
# Epoch 115/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9885 - val_loss: 1.3700
# Epoch 116/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9872 - val_loss: 1.3846
# Epoch 117/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0008 - val_loss: 1.7029
# Epoch 118/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9056 - val_loss: 1.4355
# Epoch 119/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9739 - val_loss: 1.2708
# Epoch 120/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9784 - val_loss: 1.0344
# Epoch 121/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9841 - val_loss: 1.4856
# Epoch 122/200
# 271/271 [==============================] - 3s 12ms/step - loss: 0.9536 - val_loss: 1.1660
# Epoch 123/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9936 - val_loss: 1.3389
# Epoch 124/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9477 - val_loss: 1.5457
# Epoch 125/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0072 - val_loss: 1.2880
# Epoch 126/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9468 - val_loss: 1.4986
# Epoch 127/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0506 - val_loss: 1.8978
# Epoch 128/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9720 - val_loss: 1.4715
# Epoch 129/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9279 - val_loss: 1.6175
# Epoch 130/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9242 - val_loss: 1.4813
# Epoch 131/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8831 - val_loss: 1.3932
# Epoch 132/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8766 - val_loss: 1.2867
# Epoch 133/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9696 - val_loss: 1.6088
# Epoch 134/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9144 - val_loss: 1.3146
# Epoch 135/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9462 - val_loss: 1.2276
# Epoch 136/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9842 - val_loss: 1.2035
# Epoch 137/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9171 - val_loss: 1.3398
# Epoch 138/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9120 - val_loss: 1.1569
# Epoch 139/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9616 - val_loss: 1.1894
# Epoch 140/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0341 - val_loss: 1.0249
# Epoch 141/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0066 - val_loss: 1.1921
# Epoch 142/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9221 - val_loss: 1.2027
# Epoch 143/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9329 - val_loss: 1.2611
# Epoch 144/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9215 - val_loss: 1.0341
# Epoch 145/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0120 - val_loss: 1.2905
# Epoch 146/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9864 - val_loss: 1.7095
# Epoch 147/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9902 - val_loss: 1.5187
# Epoch 148/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8540 - val_loss: 1.6170
# Epoch 149/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9030 - val_loss: 1.4953
# Epoch 150/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8912 - val_loss: 1.5211
# Epoch 151/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8912 - val_loss: 1.1641
# Epoch 152/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9344 - val_loss: 1.3172
# Epoch 153/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8796 - val_loss: 1.4730
# Epoch 154/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8761 - val_loss: 1.9532
# Epoch 155/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9671 - val_loss: 1.4214
# Epoch 156/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9227 - val_loss: 1.4476
# Epoch 157/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9045 - val_loss: 1.4602
# Epoch 158/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9341 - val_loss: 1.1343
# Epoch 159/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9243 - val_loss: 1.1708
# Epoch 160/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8257 - val_loss: 1.1250
# Epoch 161/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9300 - val_loss: 1.4090
# Epoch 162/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0032 - val_loss: 1.3249
# Epoch 163/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8246 - val_loss: 1.4128
# Epoch 164/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8733 - val_loss: 1.3332
# Epoch 165/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9081 - val_loss: 1.2141
# Epoch 166/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9679 - val_loss: 1.2655
# Epoch 167/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8760 - val_loss: 1.2313
# Epoch 168/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9539 - val_loss: 1.2500
# Epoch 169/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9089 - val_loss: 1.2464
# Epoch 170/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8405 - val_loss: 1.2420
# Epoch 171/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8456 - val_loss: 1.2803
# Epoch 172/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8792 - val_loss: 1.2320
# Epoch 173/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8693 - val_loss: 1.2367
# Epoch 174/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9409 - val_loss: 1.2686
# Epoch 175/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9490 - val_loss: 1.1341
# Epoch 176/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8958 - val_loss: 1.2523
# Epoch 177/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8175 - val_loss: 1.3477
# Epoch 178/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9171 - val_loss: 1.3036
# Epoch 179/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8719 - val_loss: 1.0955
# Epoch 180/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8219 - val_loss: 1.3642
# Epoch 181/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8950 - val_loss: 1.0915
# Epoch 182/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9165 - val_loss: 1.1697
# Epoch 183/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9661 - val_loss: 1.2848
# Epoch 184/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8791 - val_loss: 1.1910
# Epoch 185/200
# 271/271 [==============================] - 3s 11ms/step - loss: 1.0587 - val_loss: 1.2565
# Epoch 186/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9204 - val_loss: 1.4336
# Epoch 187/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8849 - val_loss: 1.3114
# Epoch 188/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9378 - val_loss: 1.4650
# Epoch 189/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9429 - val_loss: 1.3249
# Epoch 190/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8878 - val_loss: 1.1856
# Epoch 191/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9173 - val_loss: 1.3861
# Epoch 192/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9760 - val_loss: 1.1270
# Epoch 193/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8372 - val_loss: 1.3432
# Epoch 194/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8545 - val_loss: 1.1354
# Epoch 195/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8556 - val_loss: 1.2809
# Epoch 196/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9370 - val_loss: 1.2830
# Epoch 197/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8779 - val_loss: 1.1301
# Epoch 198/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.8743 - val_loss: 1.3082
# Epoch 199/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9053 - val_loss: 1.2834
# Epoch 200/200
# 271/271 [==============================] - 3s 11ms/step - loss: 0.9141 - val_loss: 1.1383

# %%
### Saving the model

import datetime
import pickle

lossFxShort = "".join([x[0] for x in lossFunction.split("_")])
modelTime = (datetime.datetime.now() + datetime.timedelta(hours=9)).strftime('%m%d_%H%M')

modelName = path+"model/cnn-fcl-direct.loss_{0}.lr_{1}.optimizer_{2}.epoch_{3}.batch_{4}.\
conv-{5}_dropout-{6}_bn-{7}_actFx-{8}.\
fcl-{9}_dropout-{10}_bn-{11}_actFx-{12}.time_{13}.keras".format(lossFxShort,
                                                                learningRate,
                                                                optimizer,
                                                                epochSize,
                                                                batchSize,
                                                                "-".join([str(k) for k in cnnFilterNumbers]),
                                                                cnnDropoutRate,
                                                                cnnBatchNormBool,
                                                                cnnActivationFunction,
                                                                "-".join([str(k) for k in fclFilterNumbers]),
                                                                fclDropoutRate,
                                                                fclBatchNormBool,
                                                                fclActivationFunction,
                                                                modelTime)

modelHistoryName = path+"modelHistory/cnn-fcl-direct.loss_{0}.lr_{1}.optimizer_{2}.epoch_{3}.batch_{4}.\
conv-{5}_dropout-{6}_bn-{7}_actFx-{8}.\
fcl-{9}_dropout-{10}_bn-{11}_actFx-{12}.time_{13}.history".format(lossFxShort,
                                                                  learningRate,
                                                                  optimizer,
                                                                  epochSize,
                                                                  batchSize,
                                                                  "-".join([str(k) for k in cnnFilterNumbers]),
                                                                  cnnDropoutRate,
                                                                  cnnBatchNormBool,
                                                                  cnnActivationFunction,
                                                                  "-".join([str(k) for k in fclFilterNumbers]),
                                                                  fclDropoutRate,
                                                                  fclBatchNormBool,
                                                                  fclActivationFunction,
                                                                  modelTime)
model.save(modelName)

with open(modelHistoryName, 'wb') as file_pi:
        pickle.dump(modelHistory, file_pi)

print("Model fully trained and saved")
# Out:
# Model fully trained and saved

# %%
### Model learning curve and summary

from matplotlib import pyplot as plt

ylimLoss = 20

plt.plot(modelHistory.history['loss'], label = "Training set")
plt.plot(modelHistory.history['val_loss'], label = "Validation set")
plt.xlabel('epoch')
plt.ylabel('loss')

plt.xticks(np.arange(0,epochSize, 20))
plt.yticks(np.arange(0,ylimLoss, 5))
plt.ylim(bottom=0, top=ylimLoss)
plt.legend()

plt.show()

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 512, 4)       112
#
#  batch_normalization (Batch  (None, 256, 512, 4)       16
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 128, 256, 4)       0
#  D)
#
#  dropout (Dropout)           (None, 128, 256, 4)       0
#
#  conv2d_1 (Conv2D)           (None, 128, 256, 8)       296
#
#  batch_normalization_1 (Bat  (None, 128, 256, 8)       32
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 128, 8)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 64, 128, 8)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 128, 16)       1168
#
#  batch_normalization_2 (Bat  (None, 64, 128, 16)       64
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 64, 16)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 32, 64, 16)        0
#
#  conv2d_3 (Conv2D)           (None, 32, 64, 32)        4640
#
#  batch_normalization_3 (Bat  (None, 32, 64, 32)        128
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 32, 32)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 16, 32, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 32, 64)        18496
#
#  batch_normalization_4 (Bat  (None, 16, 32, 64)        256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 16, 64)         0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 8, 16, 64)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 16)                131088
#
#  batch_normalization_5 (Bat  (None, 16)                64
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 156377 (610.85 KB)
# Trainable params: 156097 (609.75 KB)
# Non-trainable params: 280 (1.09 KB)
# _________________________________________________________________

# %%
### Computing evalutation metrics

from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

evalDic={}
evalDicName = path+"eval/cnn-fcl-direct.loss_{0}.lr_{1}.optimizer_{2}.epoch_{3}.batch_{4}.\
conv-{5}_dropout-{6}_bn-{7}_actFx-{8}.\
fcl-{9}_dropout-{10}_bn-{11}_actFx-{12}.time_{13}.eval".format(lossFxShort,
                                                               learningRate,
                                                               optimizer,
                                                               epochSize,
                                                               batchSize,
                                                               "-".join([str(k) for k in cnnFilterNumbers]),
                                                               cnnDropoutRate,
                                                               cnnBatchNormBool,
                                                               cnnActivationFunction,
                                                               "-".join([str(k) for k in fclFilterNumbers]),
                                                               fclDropoutRate,
                                                               fclBatchNormBool,
                                                               fclActivationFunction,
                                                               modelTime)

Y_pred = model.predict(X_test)
Y_gold = Y_test.reshape(-1,1)

mse_val = mean_squared_error(Y_gold, Y_pred)
rmse_val = mean_squared_error(Y_gold, Y_pred, squared=False)
mae_val = mean_absolute_error(Y_gold, Y_pred)
mape_val = mean_absolute_percentage_error(Y_gold, Y_pred)


r2_val = r2_score(Y_gold, Y_pred)

evalDic["subj"]=np.array(subj_test_li).reshape(-1, 1)
evalDic["pred"]=Y_pred
evalDic["gold"]=Y_gold

evalDic["mse"]=mse_val
evalDic["rmse"]=rmse_val
evalDic["mae"]=mae_val
evalDic["mape"]=mape_val
evalDic["r2"]=r2_val

with open(evalDicName, 'wb') as file_pi:
        pickle.dump(evalDic, file_pi)
    
print("Evaluation done")
# Out:
# 11/11 [==============================] - 0s 17ms/step
# Evaluation done

# %%
### Quick visualization of evaluation metrics

from matplotlib import pyplot as plt

print("Mean-squared error: {0}".format(evalDic["mse"]))
print("Root mean-squared error: {0}".format(evalDic["rmse"]))

print("Mean absolute error: {0}".format(evalDic["mae"]))
print("Mean absolute percentage error: {0}".format(evalDic["mape"]))
print("R2: {0}".format(evalDic["r2"]))

plt.scatter(evalDic["pred"], evalDic["gold"])
plt.xlabel("Predicted Age")
plt.ylabel("Actual Age")
plt.show()
# Out:
# Mean-squared error: 1.1383578461988606
# Mean absolute error: 0.8719138881718134
# Mean absolute percentage error: 0.12934579566141508
# R2: 0.4390813873974104

# %%
-
